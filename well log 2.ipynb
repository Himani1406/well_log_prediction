# %%
import pandas as pd
df= pd.read_csv("C:\\Users\\HP\\Downloads\\logdata-1.dat")
df
# Out:
#       density(g/cc)  porosity(%)  Gamma(API)  sonic(ms/m  resistivity(ohm-m)
# 0              2.75        7.000  109.947172  176.329991            7.063904
# 1              2.80       19.000  134.289780  211.380158            5.518617
# 2              2.90       25.000    4.481689  160.999977            8.805975
# 3              2.95       17.000    7.389056  160.340126            9.101752
# 4              3.00       20.000   20.085537  159.589994            9.230339
# ...             ...          ...         ...         ...                 ...
# 1403           2.18       12.656   50.000000  254.619952            5.001191
# 1404           1.46       10.551   46.804017  211.380158            5.518617
# 1405           2.37       16.931   50.680000  208.880077            5.346155
# 1406           1.46       10.551   46.804017  214.630088            5.236442
# 1407           2.37       16.931   50.680000  219.499983            5.215371
#
# [1408 rows x 5 columns]

# %%
['porosity(%)']
# Out:
# ['porosity(%)']
